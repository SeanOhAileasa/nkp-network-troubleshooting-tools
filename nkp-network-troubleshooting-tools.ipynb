# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-troubleshooting-tools/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Troubleshooting Tools``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Network Troubleshooting Tools](#topnetworkTroubleshootingTools)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topnetworkTroubleshootingToolsTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topnetworkTroubleshootingTools"></a>
# ### [Network Troubleshooting Tools](#networkTroubleshootingTools)
#
# - [Hardware Tools](#networkTroubleshootingTools1HardwareTools) <br/><br/>
#     - [Crimper](#crimper) <br/><br/>
#     - [Cable Tester](#CableTester) <br/><br/>
#     - [Punch Down Tool](#PunchDownTool) <br/><br/>
#     - [Optical Time Domain Reflectometer](#OpticalTimeDomainReflectometerOTDR) <br/><br/>
#     - [Light Meter](#LightMeter) <br/><br/>
#     - [Tone Generator](#ToneGenerator) <br/><br/>
#     - [Loopback Adapter](#LoopbackAdapter) <br/><br/>
#     - [Multimeter](#multimeter) <br/><br/>
#     - [Spectrum Analyzer](#SpectrumAnalyzer) <br/><br/>
# - [Packet Sniffer](#networkTroubleshootingTools2PacketSniffer) | [Packet Analyzer](#networkTroubleshootingTools2PacketSniffer) <br/><br/>
#     - [Wired](#WiredEnvironment) | [Wireless](#WirelessEnvironment) <br/><br/>
#         - [Software](#software) <br/><br/>
#             - [Properties](#SoftwareProperties) <br/><br/>
#     - [Troubleshooting](#TroubleshootingIdentifyThreats) | [Identify Threats](#TroubleshootingIdentifyThreats) <br/><br/>
# - [Port Scanner](#networkTroubleshootingTools3PortScanner) <br/><br/>
#     - [Attacks - Ethical](#AttacksEthicalHacking) | [Attacks - Hacking](#AttacksEthicalHacking) <br/><br/>
#     - [Scan](#) <br/><br/>
#         - [Vanilla](#VanillaTechnique) <br/><br/>
#         - [SYN](#SYNScan) <br/><br/>
#         - [FIN](#ScanFIN) | [XMAS](#ScanFIN) <br/><br/>
#         - [FTP](#ScanFTP) <br/><br/>
#         - [Sweep](#ScanSweep) <br/><br/>
#     - [System Hardened](#harden) <br/><br/>
# - [WiFi Analyzer](#networkTroubleshootingTools4WiFiAnalyzer) <br/><br/>
#     - [Statistics](#statistics) <br/><br/>
#         - [Supported Speeds](#statisticsSupportedSpeeds) <br/><br/>
#         - [Packet Retry Rates](#PacketRetryRates) <br/><br/>
#         - [Device Information](#deviceInformation) <br/><br/>
# - [Bandwidth Speed Tester](#networkTroubleshootingTools5BandwidthSpeedTester) <br/><br/>
#     - [Tools - Run in Browser](#ToolsRuninBrowser) <br/><br/>
# - [Command Line Tools](#networkTroubleshootingTools6CommandLineTools) <br/><br/>
#     - [``ping``](#PacketInternetGroper) <br/><br/>
#         - [``127.0.0.1``](#loopback) <br/><br/>
#     - [``ipconfig``](#ipconfig) <br/><br/>
#     - [``tracert``](#tracert) <br/><br/>
#     - [``pathping``](#pathping) <br/><br/>
#     - [``nslookup``](#nslookup) <br/><br/>
#     - [``arp``](#arp) <br/><br/>
#     - [``netstat``](#netstat) <br/><br/>
#     - [``route``](#route) <br/><br/>
# - [Linux Commands](#networkTroubleshootingTools7LinuxCommands) <br/><br/>
#     - [``ifconfig``](#ifconfig) <br/><br/>
#     - [``tcpdump``](#tcpdump) <br/><br/>
#     - [``iptables``](#iptables) <br/><br/>
#     - [``namp``](#namp) <br/><br/>
#     - [``dig``](#dig)

# %% [markdown]
# ### [Practice: Using Troubleshooting Tools](#practicenetworkTroubleshootingTools)
#
# * [1. Exercise: Use Network Troubleshooting Tools](#exercisenetworkTroubleshootingTools)

# %% [markdown]
# <a id="topnetworkTroubleshootingToolsTest"></a>
# ### ⚡ [Test](#networkTroubleshootingToolsTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools"></a>
# ***
# ### Network Troubleshooting Tools
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools1HardwareTools"></a>
# ***
# ###### Hardware Tools
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use hardware tools to fix network hardware issues``.

# %% [markdown]
# All right, in this presentation, we'll take a look at some of the physical tools that you will likely encounter in a network troubleshooting environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="crimper"></a>
# ***
# ###### Crimper
# ***

# %% [markdown]
# Tool used to connect an actual RJ45 plug...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ... or possibly an RJ11, to the copper wire itself (connect twisted pair cabling into the RJ45 plug).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Its often used to strip back the plastic shielding and expose the copper wire itself - crimping tools often strip and cut twisted pair cabling.
#
# Then, you quite literally can use this to clamp down a new connector to the exposed wiring, so if a cable breaks, for example, right at the connector, you can just strip back some of the wire and crimp a new connection on.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="CableTester"></a>
# ***
# ###### Cable Tester
# ***

# %% [markdown]
# Used to test whether the cable is functioning - tests pin configurations - commonly used for voice and data cables and you can identify and troubleshoot faulty cables.
#
# Some of the common tests include determining the length and return loss.
#
# > Is it's too long?
#
# > What kind of return loss you are experiencing on that cable?
#
# Can get a ``Wiremap`` so that you know that the connections on one end match the connections on the other end.
#
# So you quite literally just plug the cable into the tester, both ends, and it tells you what the wiring configuration is.
#
# Can also just use that to verify whether or not it's a straight-through cable, a crossover cable, or a rollover cable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="PunchDownTool"></a>
# ***
# ###### Punch Down Tool
# ***

# %% [markdown]
# A punch down tool is used to connect twisted pair cable into a 66 or a 110 block and they are quite simply used to connect those wires into the actual punch down block (or a patch panel most commonly these days).
#
# In essence, don't have an actual RJ45 connection going into something but rather, just the bare wire itself attaches to the back side of the patch panel, so then you just see a physical port on the front side into which you plug a regular cable.
#
# Again, this is used to make those actual connections in the back.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="OpticalTimeDomainReflectometerOTDR"></a>
# ***
# ###### Optical Time Domain Reflectometer
# ***

# %% [markdown]
# An ``OTDR`` is used to characterize and find faults in fiber cabling.
#
# It sends and measures signals, and you can actually detect where the damage is by the fact that it can measure the time it takes to reflect back, so that gives you a bit of an idea as to where any problem might be along the run.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="LightMeter"></a>
# ***
# ###### Light Meter
# ***

# %% [markdown]
# A light meter is also used for installing and testing fiber optic networks but more so in terms of signal loss and the transmission capabilities in terms of i. the power required and ii. the continuity of the cable, itself.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ToneGenerator"></a>
# ***
# ###### Tone Generator
# ***

# %% [markdown]
# A tone generator and probe is used for network testing - particularly useful if you find yourself in an environment where they have not mapped where any given cable runs terminate.
#
# A tone generator is used to determine where a cable is going, so, in other words, you see that there are several data ports in one room but you don't know where the other end is - might, of course, be in a wiring closet, but you don't physically know which ports are which, so this sends a strong magnetic signal down the cable, and then you can literally pick up on that on the other end.
#
# Can find where the other end of that cable is and you can also use this to find any cable interruptions, if present because, of course, the signal will not be detected on the other end, so you know that cable would be broken.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="LoopbackAdapter"></a>
# ***
# ###### Loopback Adapter
# ***

# %% [markdown]
# A loopback adapter is used for testing and isolating fiber optic network issues, typically this is used for the equipment itself, such as the switches.
#
# Can discover the transmission capability and the receiver sensitivity of those devices.
#
# The transmission capability and receiver sensitivity of devices are determined through equipment testing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="multimeter"></a>
# ***
# ###### Multimeter
# ***

# %% [markdown]
# A multimeter is a standard electrical diagnostics tool used to measure:
#
# - voltage - which measures the volts
#
#
# - current - which measures the amps
#
#
# - resistance - which measures the ohms
#
#
# Resistance measurement is a fairly common when troubleshooting connectivity issues because if any two points of a connection don't have the same ohmage then you are likely to encounter problems, for sure.
#
# Again, useful when you just need to ascertain that electrical information.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="SpectrumAnalyzer"></a>
# ***
# ###### Spectrum Analyzer
# ***

# %% [markdown]
# A spectrum analyzer is widely used in radio frequency testing during development, verification, validation, production, and/or repair - Radio Frequency is also referred to as RF.
#
# In essence, this provides insight into the radio frequency performance of any given area, particularly with respect to how far the signal is carrying and/or how much it is being interfered with by anything that can cause electromagnetic interference, so you can get a bit of an idea as to what your implementation will look like and how it will perform by using the spectrum analyzer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Basic understand of the Tools
# ***

# %% [markdown]
# The tools that you might encounter will certainly vary once you get into a troubleshooting environment but it's useful to have a basic understanding of each of them so that you understand what they're used for.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools2PacketSniffer"></a>
# ***
# ###### Packet Sniffer | Packet Analyzer
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use a packet sniffer to intercept and log network traffic``.
#
# Packet sniffers - commonly referred to as protocol analyzers - are used to intercept and log network traffic.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="WiredEnvironment"></a>
# ***
# ###### Wired Environment
# ***

# %% [markdown]
# In a wired network, it can depend on what the configuration is in terms of segmentation and switch configuration, with respect to how much traffic you can see.
#
# In other words, typically are limited to the traffic within that segment but they are able to capture the packets that are traveling around on the network and they can present them to you in a very readable format, so you literally see the contents of the packets, including the data, in many cases, and the protocols that are being used - hence the term, protocol analyzer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="WirelessEnvironment"></a>
# ***
# ###### Wireless Environment
# ***

# %% [markdown]
# If its a wireless environment, then typically you can still do this, but it's usually only one channel at a time but they are just used to see what's actually traveling around on the network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="software"></a>
# ***
# ###### Software
# ***

# %% [markdown]
# It does require this particular software that's able to present the information to you in a legible format, as opposed to just saying there are ``X`` number of packets.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="SoftwareProperties"></a>
# ***
# ###### Software - Properties
# ***

# %% [markdown]
# These analyzers present the content of the packets as well, so the information can include the message sent between the two parties - can, in fact, capture passwords that have been sent in clear text - will still show encrypted passwords as encrypted - can also identify website history, see images being accessed, capture account information.
#
# So of course, they're useful in understanding what kind of information is traveling around on your network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="TroubleshootingIdentifyThreats"></a>
# ***
# ###### Troubleshooting | Identify Threats
# ***

# %% [markdown]
# Protocol analyzers can certainly be used in network troubleshooting to perform diagnostic testing - can monitor the activity and troubleshoot network problems because if packets, for example, are not arriving at the intended destination or just arriving but yet in an unreadable format, then you can hopefully find out what is causing the problem.
#
# Can also identify threats to a network, such as hackers, by identifying protocols that are being allowed in that shouldn't be allowed in, so in other words, you can kind of assess your environment for vulnerabilities.
#
# Ironically, of course, hackers also use packet sniffers extensively to try and find the very same vulnerabilities so that they can exploit them but of course, as a network technician or possibly even a security analyst, you are looking for those threats to try to mitigate them.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Picture of the Traffic
# ***

# %% [markdown]
# Either way, a Packet Sniffer (Packet Analyzer) can be very useful for just getting a better picture of what the traffic looks like within your network environment so that you can better address problems when they arise.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools3PortScanner"></a>
# ***
# ###### Port Scanner
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use a port scanner to identify which ports are open on a network``.
#
# Port scanning is a technique used to identify which ports are open on a network because, of course, ports are used by a computer to send and receive information.
#
# So from the perspective of an attacker, a port represents a possible means of access and an analogy is, quite simply, knocking on each door in the neighborhood to see if anyone is home and if you are looking to intrude, then you won't intrude on a house where people are home but will focus your attention on one where no one is home.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="AttacksEthicalHacking"></a>
# ***
# ###### Attacks - Ethical | Hacking
# ***

# %% [markdown]
# In terms of attacks, there are two types of approaches:
#
# i. ethical hacking, whereby an organization will perform port scanning to identify possible openings in their network but by doing so, they are trying to identify the vulnerabilities to correct them, so they can secure the network from these threats - by identifying possible openings in their network, organizations can implement changes to secure the network from outside threats, so they use the same techniques as hackers, but for a legitimate purpose.
#
# Hacking, of course, refers to identifying these potential openings for personal gain, so that you can exploit and access the network for unethical reasons.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="VanillaTechnique"></a>
# ***
# ###### Scan - Vanilla Technique (Synchronization Flag - SYN - Initiate a Full Connection)
# ***

# %% [markdown]
# There is a method known as the ``Vanilla Technique``, which is a basic port scan, whereby a system attempts to connect to all ``65,536`` ports at once.
#
# This issues a full connect scan that sends requests to connect, in other words, it uses what's known as a ``SYN`` - ``Synchronization Flag`` - to actually initiate a full connection.
#
# These are fairly effective in terms of discovering which ports are open but they're also easily detectable because firewalls will always log a full connect request.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="SYNScan"></a>
# ***
# ###### Scan - Synchronization SYN (Initiate a half-open Connection)
# ***

# %% [markdown]
# There's also a ``SYN`` scan, which is a half open scan - the attacking system will send a ``SYN`` request and wait for an acknowledgement response - the attacking system waits for a return ``SYN-ACK`` response.
#
# The scanner or the attacker does not respond to any of the received responses and as such, the system does not log the interaction, so in this way, the sender learns if a port is open or not without it being logged by that system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ScanFIN"></a>
# ***
# ###### Scan - FIN - XMAS (Christmas)
# ***

# %% [markdown]
# There are also types of scans known as ``FIN`` scans and ``XMAS`` (or Christmas) scans and these ones are usually targeted on a specific port, but they use a variety of the flags that they use to initiate the connection.
#
# An unsolicited ``FIN`` flag is sent to a system, whereby it can determine the state of the port based on the response - it's not trying to find every port, it's now trying to find a specific port and trying to obtain the state and the protocol information for that port - revealing the state of the port provides insight about the firewall.
#
# A ``Christmas`` scan is simply sending a set of flags, usually the complete set of all flags - this ends up creating, in essence, a fairly nonsensical interaction, if you will - the system doesn't really know what to do, because it's receiving every possible type of connection request, so, again, determinations can be made based on the responses that come back.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ScanFTP"></a>
# ***
# ###### Scan - FTP Bounce
# ***

# %% [markdown]
# An ``FTP`` bounce scan allows the attacker to effectively disguise their location - sending the packets through an open ``FTP`` server so that the sender can perform their attack undetected.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ScanSweep"></a>
# ***
# ###### Scan - Sweep
# ***

# %% [markdown]
# A ``sweep`` scan sends a number of ``ping`` commands to the same port on multiple computers to identify which devices on the network are active - those that respond have an open port, so that presents the avenue of attack.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="harden"></a>
# ***
# ###### Conclusion - Systems Hardened
# ***

# %% [markdown]
# Ideally, to reduce the chance of falling victim to port scanning attacks, you should really just ensure that your systems are hardened, in other words, if you do not use that port then, quite simply, disable it - for those that are open, ensure that they are configured correctly on your firewalls so that only the appropriate traffic is allowed through.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools4WiFiAnalyzer"></a>
# ***
# ###### WiFi Analyzer
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use a WiFi analyzer to detect usage``.
#
# A WiFi analyzer is typically software that is run on a laptop, tablet or a smartphone, essentially a mobile device in most cases and there are also some dedicated hardware devices to perform the same task but they essentially enable you to scan and detect WiFi usage on various bands and channels in addition to detecting any source of interference.
#
# This is particularly useful when planning a WiFi network, you essentially want to survey and map the site - this is always a good place to start because, in particular, sources of interference can be quantified and clear channels can be found.
#
# In essence, don't just want to blindly place your wireless access points and assume that they will have the coverage that you expect because there can be a lot of different components that might interfere with that signal, so ideally, you want to quite literally map out what the signal looks like so you can place your access points accordingly.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="statistics"></a>
# ***
# ###### Statistics
# ***

# %% [markdown]
# Can also gather several statistics about the communication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="statisticsSupportedSpeeds"></a>
# ***
# ###### Statistics - Supported Speeds (Data Transmission Rates)
# ***

# %% [markdown]
# Can find out what the supported speeds are, the maximum data transmission rates.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="PacketRetryRates"></a>
# ***
# ###### Statistics - Packet Retry Rates (Data Transmission and Network Coverage)
# ***

# %% [markdown]
# Packet Retry Rates, allows you to identify issues with data transmission and network coverage.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="deviceInformation"></a>
# ***
# ###### Statistics - Device Information
# ***

# %% [markdown]
# Can also gain access to device information with respect to what is connected to the wireless network - this can allow you to assemble an inventory of those devices, and of course, determine what kind of hardware might be needed to better implement the overall solution.
#
# > Maybe lacking an access point in this particular area?
#
# Does it seem like:
#
# > Maybe, you have too many in one particular area, so that perhaps you could relocate one to get better coverage overall?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Effective Coverage - Efficient Use of Devices
# ***

# %% [markdown]
# In many cases, it's just good to know what the coverage looks like so you can get the most effective coverage with the most efficient use of your devices.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools5BandwidthSpeedTester"></a>
# ***
# ###### Bandwidth Speed Tester
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use a bandwidth speed tester``.
#
# Another useful tool when troubleshooting network connectivity is the ``Bandwidth Speed Tester`` because, of course, you might expect to see a certain value in terms of bandwidth but you might not be getting it and this is because your speed can be reduced by a number of factors - including the distance that's being covered, the quality of the wiring, the network devices, such as your routers and switches, and even the time of day - more specifically, the amount of traffic at that particular time of day, for example, things might be a lot busier during the middle of the afternoon than they would be in the evening, depending on how your environment works, but it can take into account those different types of factors.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ToolsRuninBrowser"></a>
# ***
# ###### Tools - Run in Browser
# ***

# %% [markdown]
# There are a number of different tools that can test the overall speed, but these days it's very common to simply use a browser.
#
# There are a lot of online speed testers.
#
# They would only give you the speed of your Internet connection, but that's still useful to know as well.
#
# They will typically issue out a ``ping`` to a location within the network of the ISP themselves and then report back the statistical information about that ``ping``.
#
# How long it took and how much packet loss there was and then it quite literally performs a download and an upload, and reports back the overall speed that was achieved for that particular test.
#
# Can issue this is as many times that you want to get a very good picture of what things look like throughout the day with those varying conditions - ultimately, it tells you, flat out, this is the speed that we were able to achieve, so if you feel like you should be getting something better, then, of course, you can start to investigate a little more deeply but at least you know what the values are now and again, these tools are widely available online, and they're free - very useful for just getting a very good picture of what your actual bandwidth looks like.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools6CommandLineTools"></a>
# ***
# ###### Command Line Tools
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use network troubleshooting command line tools``.
#
# Overview of the many Windows command line tools that you can use for testing and troubleshooting network connectivity.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="PacketInternetGroper"></a>
# ***
# ###### Packet Internet Groper (PING)
# ***

# %% [markdown]
# A utility that can be used to simply test connectivity between two hosts - quite literally:
#
# > Can I see you?
#
# > Can you see me?
#
# It uses the ``Internet Control Message Protocol`` - ``ICMP`` - and determines, quite simply, the status of any given remote host.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="loopback"></a>
# ***
# ###### PING - Loopback
# ***

# %% [markdown]
# Can also ``ping`` yourself, so to speak, the loopback address is used to determine if ``TCP/IP`` is installed.
#
# This is the same for every system running Windows - that address is reserved and, in essence, is bound to every adapter and it indicates if ``TCP/IP`` has correctly configured itself on the network interface.
#
# So if you are having connectivity issues, one of the first things to try is simply ``ping`` the loopback address and the syntax is, quite literally:
#
#
# ``ping 127.0.0.1``
#
#
# Can, in many cases, also ``ping localhost`` - resolves to ``127.0.0.1`` and again, it just tells you that your own network interface has ``TCP/IP`` installed correctly on itself.
#
#
# Then you can work out from that point and ``ping`` other IP addresses, or in fact, you can also, in most cases, ``ping`` a ``DNS`` name, so, for example, you could:
#
#
# ``ping server1.mydomain.com``
#
#
# Even Internet names as well, you can:
#
#
# ``ping www.yourfavoritewebsite.com``
#
#
# In many cases, Internet pinging might not yield any results because many routers on the Internet will simply discard ping packets to prevent them from being pinged too often.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ipconfig"></a>
# ***
# ###### ``ipconfig``
# ***

# %% [markdown]
# ``ipconfig`` is perhaps one of the most common tools - used to determine your network configuration - displays the current TCP/IP address information and some of the main commands include:
#
#
# - ``ipconfig /all``
#
#
# - ``ipconfig /release``
#
#
# - ``ipconfig /renew``
#
#
# ``ipconfig /all`` - just gives you much more detailed information - your IP address, your subnet mask and your default gateway but ``/all`` will give you your ``DNS`` server, your ``DHCP`` server, lease information with respect to when you got the address and when it's validity period expires, things along those lines.
#
# Specifically, the ``/release`` and the ``/renew`` pertain to your ``DHCP`` configuration - if you feel like you received an incorrect or invalid address, you can discard the address by issuing: ``ipconfig /release`` then ``ipconfig /renew`` initiates a request for a new address from the ``DHCP`` server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="tracert"></a>
# ***
# ###### Traceroute (``tracert``)
# ***

# %% [markdown]
# ``tracert`` or more commonly referred to as ``traceroute`` (linux), is a command that can show several details about the path that packets take, in other words, from your device to the destination.
#
# This is a routing tool and again, often referred to as ``traceroute`` but it is, quite literally, the path of routers that are being crossed as a packet travels from the source to the destination.
#
# This is generally only useful when you are troubleshooting network paths within your own internetworking environment, for example, if you feel like a package should travel this route and it's going all over the place, then you can possibly try to troubleshoot your routers to redirect it a little bit better.
#
# Can see the path that it takes over the Internet but, of course, there's not much you can do about changing the path on the Internet, but useful, again, for internal routing.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="pathping"></a>
# ***
# ###### ``pathping`` (Multiple Echo Request messages)
# ***

# %% [markdown]
# ``pathping`` is kind of similar to ``ping`` and ``tracert`` put together - its used to identify network latency and network loss issues.
#
# ``Multiple Echo Request`` messages are sent to each router over a period of time and the results are computed based on information that is received back from those routers to identify problems with the router configuration or the way that you have implemented your subnets.
#
# The command supports multiple parameters to refine it, but, in essence, it kind of combines ``ping`` with ``traceroute`` so that you can get statistical information about the route that packets take.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### ``nslookup``
# ***

# %% [markdown]
# The ``nslookup`` command line tool is a network utility program.
#
# ``nslookup`` is used to diagnose ``DNS`` problems - ``Domain Name Service`` - returning the IP address that matches the hostname that you supply or vice versa but you can also verify which ``DNS`` server is responding to the request, so if you suspect that perhaps a rogue ``DNS`` server has been introduced into the environment, ``nslookup`` will tell you which server satisfied that request.
#
# This is only available, of course, if ``TCP/IP`` is installed, but it can also do reverse name lookup - you can return the IP address matching a name or you can return the name matching an IP address - either way, you still get the correct resolution of this address to that name.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="arp"></a>
# ***
# ###### Address Resolution Protocol (ARP) - Resolves the IP address to a MAC address
# ***

# %% [markdown]
# ``arp`` refers to the ``Address Resolution Protocol`` - this is a command used to manage our cache information for network devices - the ``arp`` command line tool is an external command.
#
# Can display the cache, or you can in fact add or remove a value from the cache - recall that ``ARP resolves the IP address to a MAC address``.
#
# It's possible that a system might have changed its IP address, but yet the cache still believes that it's using its previous IP address, so if that's the case, then packets will be routed to the incorrect address, so you can purge out the cache entirely, or you could just remove that single entry.
#
# Conversely, if you have a system that you know always has the same IP address and it's always attached to the same MAC address, then you can actually add persistent entries to the cache and they'll be resolved more quickly.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### ``netstat``
# ***

# %% [markdown]
# ``netstat`` is used to display and check if various aspects of ``TCP/IP`` are working, such as your network connections, both incoming and outgoing - can see the status of your routing tables - can also see the statistics of your network interface with respect to the protocols and the port status - can see which ports are open and which protocols are being used over those ports.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="route"></a>
# ***
# ###### ``route``
# ***

# %% [markdown]
# ``route`` is used to manually configure a routing table - this is typically only used when you have a Windows Server, for example, that is being used as a router, which isn't particularly common but can certainly still be done, so this is used to quite literally ``add``, ``delete``, or ``change`` the static routing entries that you have for that server, for example, you can issue the command ``route add`` to manually add a new route.
#
#
# - ``<destination>`` is the network to which this packet is destined
#
#
# - ``mask`` is the subnet mask in use for that destination network
#
#
# - ``<gateway>`` is, in essence, the default gateway that you see from your perspective to get out
#
#
# - ``metric`` is the distance how many hops
#
#
# - ``<interface>`` is the one that you see as being the doorway into that network
#
#
# ```
# route add <destination> mask <netmask> <gateway> metric <interface>
# ```
#
# So you quite literary specify those values, that adds the route, and that server now knows how to route a packet to that destination network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Depends on System Configuration
# ***

# %% [markdown]
# So, again, it depend on the configuration of any given system with respect to which commands you will use but you may very well encounter all of those when troubleshooting connectivity issues.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingTools7LinuxCommands"></a>
# ***
# ###### Linux Commands
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use Linux command line tools``.
#
# Looking at some command line tools used for testing and troubleshooting network connectivity, but this time, some of the commands that you will likely see in a Linux environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ifconfig"></a>
# ***
# ###### ``ifconfig``
# ***

# %% [markdown]
# ``ifconfig`` is the tool used to manage the network interface and the basic configuration information such as assigning an address, configuring address properties, and simply displaying the current configuration.
#
# This is effectively the equivalent of ``ipconfig`` in a Windows environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="tcpdump"></a>
# ***
# ###### ``tcpdump`` (same in ``.pcap`` format)
# ***

# %% [markdown]
# The ``tcpdump`` tool is used to capture or filter ``TCP/IP`` packets and you can save the captured packets for future analysis in ``.pcap`` format and this can be viewed using the ``tcpdump`` command itself, or there are various open source GUI-based tools that you can use.
#
# This is similar to ``Network Monitor`` in Windows, whereby you simply capture the traffic and then you can analyze to see what the contents are and, of course, the protocol information and the address information for testing and troubleshooting various connectivity issues.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="iptables"></a>
# ***
# ###### ``iptables``
# ***

# %% [markdown]
# ``iptables`` is used to manage tables of ``IPv4`` packet filter rules.
#
# This allows you to do some basic firewalling - can set up, maintain, and inspect these rules and they are stored in tables and they can contain numerous built-in and user-defined chains, so one rule can flow down to another rule, in essence and you can decide what to do with any given packet based on the criteria that you specify.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="namp"></a>
# ***
# ###### ``namp``
# ***

# %% [markdown]
# ``nmap`` is essentially a network mapper, which is an open source security scanner that is widely used for exploration, security, auditing, and scanning.
#
# It is generally available as a command line but there are also several graphical user interface versions.
#
# In essence, this typically just presents you with an overall picture of the network environment and, again, commonly used in auditing and/or security analysis, so you can present someone with a report that says here are the vulnerabilities that we discovered in your network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="dig"></a>
# ***
# ###### ``dig``
# ***

# %% [markdown]
# ``dig`` is a command line tool used to query ``DNS`` nameservers - is a network administration command line tool
#
# Can obtain host addresses, find out which servers are the mail exchangers, which ones are the nameservers, and various other related information, effectively, equates to the ``nslookup`` tool in Windows - just gathering up that information about servers that handle name resolution.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Bit of Crossover
# ***

# %% [markdown]
# These are commonly used in the Linux environments but some of them are actually supported in Windows, as well and, in fact, some of the Windows commands might also be supported in certain Linux environments, so there's a little bit of crossover between the two but, generally, you'll find these commands used more so in the Linux or Unix world.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practicenetworkTroubleshootingTools"></a>
# ***
# ### Practice: Using Troubleshooting Tools
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use various network troubleshooting tools``.
#
#
# i. Describe when to use a packet sniffer.
#
#
# ii. Describe when to use a WiFi Analyzer.
#
#
# iii. Recognize when to use a tone generator.
#
#
# iv. Describe the use of the ``ping`` command.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exercisenetworkTroubleshootingTools"></a>
# ***
# ###### 1. Exercise: Use Network Troubleshooting Tools
# ***

# %% [markdown]
# i. Describe when to use a packet sniffer.
#
# Used to intercept and log network traffic, and typically it's used when performing analysis of the network traffic, either for troubleshooting purposes or to identify vulnerabilities - it's often used in terms of doing security assessments of any given environment to find out where those weaknesses exist and then, of course, so that they can be addressed.

# %% [markdown]
# ii. Describe when to use a WiFi Analyzer.
#
# Typically used when planning, surveying, or mapping a WiFi network so that you can identify sources of interference and they can be quantified, and essentially, the clearest channels can be found so that you can have the most efficient and effective implementation of your Wi-Fi access points.

# %% [markdown]
# iii. Recognize when to use a tone generator.
#
# Typically, this is used to determine cable termination points or to locate damaged cables - in many cases, you might find yourself in an environment where you simply don't know where the other end of any given data port actually reside, so you can send this signal down that cable and then you can quite literally pick up on it on the other end and if you can't find anything at all then this would likely indicate the cable itself is broken.

# %% [markdown]
# iv. Describe the use of the ``ping`` command.
#
# This simply determines the status of a remote host, or the status of your own network interface - if you receive a reply from your own interface and from a remote host, you essentially can assume that connectivity is working, but in some cases, you can also get the statistical information about the reply from that host to determine if any packets are being lost and/or how stable the connection is, so you can simply assess how effectively you are communicating with any given remote host.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshootingToolsTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
